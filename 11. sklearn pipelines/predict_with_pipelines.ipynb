# %% [markdown]
# <h1 style="color:red">Predicting using pipelines</h1>

# %%
import pickle
import numpy as np

# %%
# importing the pipeline object from the 'pipeline_model/...' with the same name as used while exporting
# these objects will behave same as they where behaving in the original file 

pipe = pickle.load(open('pipeline_model/pipe.pkl','rb'))

# %%
# Assume user input
# Pclass/gender/age/SibSp/Parch/Fare/Embarked 
test_input = np.array([2,'male', 34, 1,2, 36.2, 'S'], dtype=object).reshape(1,7)

# %%
test_input
# Out:
# array([[2, 'male', 34, 1, 2, 36.2, 'S']], dtype=object)

# %%
pipe.predict(test_input)
# Out:
# C:\Users\rupes\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# C:\Users\rupes\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# array([0])

# %%
# This warning occurs because the pipeline was trained with DataFrame feature names 
# but prediction was done using a NumPy array without column names; 
# it does not affect the prediction but should be fixed by passing a DataFrame.
