# %% [markdown]
# <h1> Exploratory Data Analysis (EDA)</h1>

# %%
# The preliminary analysis of data to discover relationships between measures in the data and to gain an insight on the 
# trends, patterns, and relationships among various entities present in the data set with the help of 
# statistics and visualization tools is called Exploratory Data Analysis (EDA).

# %% [markdown]
# <h2 style="color:red"> Univariate Analysis</h2>

# %%
# Uni means one and variate means variable, so in univariate analysis, there is only one dependable variable.

# %%
import pandas as pd

# %%
df = pd.read_csv("titanic.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# <h2 style="color:red"> 1. Categorical Data</h2>

# %% [markdown]
# <h3 style="color:blue">a). countplot()</h3>

# %%
display(df["Pclass"].value_counts())
df["Pclass"].value_counts().plot(kind='bar')
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64
# <Axes: xlabel='Pclass'>

# %%
import seaborn as sns               #  Advanced statistical visualizations
sns.countplot(x=df['Survived'])     # countplot() expects keyword arguments like x= or y=
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %% [markdown]
# <h3 style="color:blue">b). PieChart</h3>

# %%
df['Embarked'].value_counts().plot(kind='pie', autopct="%.2f")
# Out:
# <Axes: ylabel='count'>

# %%
df['Sex'].value_counts().plot(kind='pie', autopct="%.2f")
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# <h2 style="color:red"> 2. Numerical Data</h2>

# %% [markdown]
# <h3 style="color:blue">a). HistoGram </h3>

# %%
import matplotlib.pyplot as pyplot      #  Basic plotting library

# %%
pyplot.hist(df['Age'])
pyplot.xlabel("Age")               # X-axis label
pyplot.ylabel("Frequency")         # Y-axis label
pyplot.title("Age Distribution")   # Plot title
pyplot.show()

# %%
pyplot.hist(df['Age'],bins= 20)           # bins helps you to decide in how many intervals you want to distribute the data
# Out:
# (array([40., 14., 15., 31., 79., 98., 85., 84., 73., 45., 35., 35., 29.,
#         16., 13., 11.,  4.,  5.,  1.,  1.]),
#  array([ 0.42 ,  4.399,  8.378, 12.357, 16.336, 20.315, 24.294, 28.273,
#         32.252, 36.231, 40.21 , 44.189, 48.168, 52.147, 56.126, 60.105,
#         64.084, 68.063, 72.042, 76.021, 80.   ]),
#  <BarContainer object of 20 artists>)

# %%
sns.histplot(df["Age"],bins= 10, kde=True, linewidth=0)   # kde=True adds density curve,    KDE = smooth probability curve
# edgecolor='none' or linewidth=0 removes the border of individual bins
pyplot.title("Age Distribution with KDE")
pyplot.show()

# %% [markdown]
# <h3 style="color:blue">b). DistPlot </h3>

# %%
# Discontinued
# sns.distplot(df["Age"],bins= 10)

# %% [markdown]
# <h3 style="color:blue">c). Box Plot </h3>

# %% [markdown]
# <!-- ![Box-Plot](Box-Plot.png) -->
#
# <div align="center">
#   <img src="Box-Plot.png" width="600">
# </div>

# %%
# A box plot summarizes a numerical variable using quartiles, median, spread, and outliers in a single visual.
# Dots outside whiskers = outliers,  Median line inside box

sns.boxplot(x=df['Fare'])      # we can remove outliers as these may effect the expected outcome
pyplot.title("Boxplot for Fare")
pyplot.show()

# %%
sns.boxplot(x = df['Age'])
# Out:
# <Axes: xlabel='Age'>

# %% [markdown]
# <h3 style="color:blue">d). Other Analysis </h3>

# %%
df['Age'].skew()           #  Checking Skewness

# Interpretation:
# > 0 → Right skewed
# < 0 → Left skewed
# ≈ 0 → Symmetric
# Out:
# np.float64(0.38910778230082704)

# %%
df['Age'].max()
# Out:
# 80.0

# %%
df['Age'].min()
# Out:
# 0.42

# %%
df['Age'].mean()
# Out:
# np.float64(29.69911764705882)

# %%
df['Age'].median()
# Out:
# 28.0

# %%
df['Age'].mode()
# Out:
# 0    24.0
# Name: Age, dtype: float64

# %%
df.count()
# Out:
# PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# Age            714
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# Cabin          204
# Embarked       889
# dtype: int64

# %%
df['Fare'].sum()
# Out:
# np.float64(28693.9493)

# %%
print("No. of Passenger with Fare > 50 is:", df['Fare'][df['Fare'] > 50].count())

df['Fare'][df['Fare'] > 50]
# Out:
# No. of Passenger with Fare > 50 is: 160
# 1       71.2833
# 3       53.1000
# 6       51.8625
# 27     263.0000
# 31     146.5208
#          ...
# 856    164.8667
# 863     69.5500
# 867     50.4958
# 871     52.5542
# 879     83.1583
# Name: Fare, Length: 160, dtype: float64

# %%
df['Ticket'].duplicated().sum()
# Out:
# np.int64(210)

# %%
df.sort_values(by='Embarked', ascending=False, ignore_index=True)
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 0              1         0       3                    Braund, Mr. Owen Harris
# 1            555         1       3                         Ohman, Miss. Velin
# 2            541         1       1                    Crosby, Miss. Harriet R
# 3            542         0       3       Andersson, Miss. Ingeborg Constanzia
# 4            543         0       3          Andersson, Miss. Sigrid Elisabeth
# ..           ...       ...     ...                                        ...
# 886           97         0       1                  Goldschmidt, Mr. George B
# 887          545         0       1                 Douglas, Mr. Walter Donald
# 888          382         1       3                Nakid, Miss. Maria ("Mary")
# 889           62         1       1                        Icard, Miss. Amelie
# 890          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
# ...
