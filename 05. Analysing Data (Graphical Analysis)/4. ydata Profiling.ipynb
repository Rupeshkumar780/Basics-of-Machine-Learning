# %%
# !pip install ydata-profiling

# %%
import pandas as pd
from ydata_profiling import ProfileReport

# %%
df = pd.read_csv('titanic.csv')
prof = ProfileReport(df)
prof.to_file(output_file='output.html')
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# %|                                                                                           | 0/12 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 12/12 [00:00<00:00, 83.08it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
df2 = pd.read_csv('Student_Mental_Health_Academic_Pressure.csv')
df2.head()
# Out:
#             Timestamp Age Group   Gender\n     Current Education Level    \
# 0  12/13/2025 6:18:33     15–18       Female                     College
# 1  12/13/2025 6:24:50     15–18         Male                     College
# 2  12/13/2025 6:29:50     15–18       Female                  University
# 3  12/13/2025 7:36:26       27+         Male                       Other
# 4  12/13/2025 8:01:20     15–18       Female                     College
#
#      How much academic pressure do you feel?    \
# 0                                            4
# 1                                            4
# 2                                            3
# 3                                            1
# 4                                            2
#
#    How often do you feel stressed due to studies?  \
# 0                                       Sometimes
# 1                                           Often
# 2                                       Sometimes
# 3                                          Always
# 4                                       Sometimes
#
#     How many hours do you sleep on average per night?    \
# 0                                                7–8
# 1                                                5–6
# 2                                                7–8
# 3                                                7–8
# 4                                                5–6
#
#     What is the main cause of your academic stress?
# 0                      1 .Exam and grades pressure
# 1                          Exams and Grades Pressure
# 2                              financial conditions
# 3                                             Other
# 4                                  Prefer not to say

# %%
from ydata_profiling import ProfileReport
report = ProfileReport(df2)
report.to_file("Student_Mental_Health_Academic_Pressure.html")
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# %|                                                                                            | 0/8 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 41.35it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
